# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://en.wikipedia.org/wiki/List_of_Nobel_laureates"
soup = BeautifulSoup(requests.get(url).content, "html.parser")

# %%
titles=[i.text for i in soup.find("table",{"class":"wikitable"}).find_all("th")]
case=0
if titles[0]==titles[int(len(titles)/2)]:
    titles= [i.replace("\n","").split("[")[0] for i in titles[0:int(len(titles)/2)]]
    case=1
else:
    titles= [i.replace("\n","").split("[")[0] for i in titles]
    case=2

if case==1:
    rows=[i.text.split("\n")[1::2] for i in soup.find("table",{"class":"wikitable"}).find_all("tr")[1:-1]]

if case==2:
    rows=[i.text.split("\n")[1::2] for i in soup.find("table",{"class":"wikitable"}).find_all("tr")[1:]]

# %%
df=pd.DataFrame(rows,columns=titles)
df
# Out:
#      Year                                           Physics  \
# 0    1901                                   Wilhelm Röntgen
# 1    1902                     Hendrik Lorentz;Pieter Zeeman
# 2    1903          Henri Becquerel;Pierre Curie;Marie Curie
# 3    1904                                     Lord Rayleigh
# 4    1905                                    Philipp Lenard
# ..    ...                                               ...
# 116  2017              Rainer Weiss;Barry Barish;Kip Thorne
# 117  2018      Arthur Ashkin;Gérard Mourou;Donna Strickland
# 118  2019        James Peebles; Michel Mayor; Didier Queloz
# 119  2020    Roger Penrose; Reinhard Genzel; Andrea M. Ghez
# 120  2021  Syukuro Manabe; Klaus Hasselmann; Giorgio Parisi
#
#                                              Chemistry  \
# 0                         Jacobus Henricus van 't Hoff
# 1                                 Hermann Emil Fischer
# 2                                     Svante Arrhenius
# ...
