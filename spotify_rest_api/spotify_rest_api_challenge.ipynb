# %% [markdown]
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` a generate your __token__ access

# %%
# generate token with a POST request

client_id = "1cff8653d6ee48b1a66b60459ec7c062"
client_secret = "224b61f1e21343beb0abfdac7d56d94e"
auth_url = 'https://accounts.spotify.com/api/token'

auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()
access_token = auth_response['access_token']
access_token
# Out:
# 'BQB0NtaAMY-3FWQShQvLgQ0sLirUglQYNEhPcm4wWHZMSaBIghTz4uUNnmGupWzSyYtzsqF2htAY7Ecuno4'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point) and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1'
resource = '/artists'
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# artist: 36QJpDe2go2KgaRleHCDTp

# %%
artist="/36QJpDe2go2KgaRleHCDTp"
type1="/related-artists"


response = requests.get(base_url+resource+artist+type1, headers=headers).json()
related_artists=pd.DataFrame(response["artists"])
related_artists[["name","uri"]]
# Out:
#                     name                                    uri
# 0            Deep Purple  spotify:artist:568ZhdwyaiCyOGJRtNYhWf
# 1           Jimi Hendrix  spotify:artist:776Uo845nYHJpNaStv1Ds4
# 2              The Doors  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 3                  Cream  spotify:artist:74oJ4qxwOZvX6oSsu1DGnw
# 4                The Who  spotify:artist:67ea9eGLXYMsO2eYQRui3w
# 5           Robert Plant  spotify:artist:1OwarW4LEHnoep20ixRA0y
# 6    Grand Funk Railroad  spotify:artist:0qEcf3SFlpRcb3lK3f2GZI
# 7         Lynyrd Skynyrd  spotify:artist:4MVyzYMgTwdP7Z49wAZHx0
# 8       Blue Öyster Cult  spotify:artist:00tVTdpEhQQw1bqdu8RCx2
# 9                 ZZ Top  spotify:artist:2AM4ilv6UzW0uMRuqKtDgN
# 10         Black Sabbath  spotify:artist:5M52tdBnJaKSvOpJGz8mfZ
# 11           Steppenwolf  spotify:artist:1WRM9i067hd2ujxxi8FI3m
# 12      The Black Crowes  spotify:artist:5krkohEVJYw0qoB5VWwxaC
# 13            Thin Lizzy  spotify:artist:6biWAmrHyiMkX49LkycGqQ
# 14     Steve Miller Band  spotify:artist:6QtGlUje9TIkLrgPZrESuk
# 15            Ted Nugent  spotify:artist:21ysNsPzHdqYN2fQ75ZswG
# 16                  Free  spotify:artist:2e53aHBQdCMKWqHDuyJsjC
# 17  Allman Brothers Band  spotify:artist:4wQ3PyMz3WwJGI5uEqHUVR
# 18          Alice Cooper  spotify:artist:3EhbVgyfGd7HkpsagwL9GS
# 19    The Rolling Stones  spotify:artist:22bE4uQ6baNwSHPVcDxLCe

# %%
type2="/top-tracks"
country="?market=ES"
top_artists_tracks=pd.DataFrame()
for i in related_artists["id"]:
    response2= requests.get(base_url+resource+"/"+i+type2+country, headers=headers).json()
    top_tracks=pd.DataFrame(response2["tracks"])
    top_artists_tracks=top_artists_tracks.append(top_tracks)

top_artists_tracks[["name","uri"]]
# Out:
#                                           name  \
# 0         Smoke On The Water - Remastered 2012
# 1               Highway Star - Remastered 2012
# 2                            Perfect Strangers
# 3   Soldier Of Fortune - 2009 Digital Remaster
# 4                         Hush - 1998 Remaster
# ..                                         ...
# 5            Beast Of Burden - Remastered 1994
# 6                                        Angie
# 7                       Wild Horses - 2009 Mix
# 8                        Miss You - Remastered
# 9                  Brown Sugar - 2009 Remaster
#
#                                      uri
# 0   spotify:track:5MMnwYs0hIxkENRsbkWJ2G
# 1   spotify:track:3uMmllZo1AfoEnVT4ENCD3
# 2   spotify:track:2JhJOPGvtqMpj5RQC8cIYf
# 3   spotify:track:60ifqqPhbselSwXyGrGyMK
# 4   spotify:track:2Vim06YsRb4uJRpbeq6NR6
# ..                                   ...
# 5   spotify:track:77oU2rjC5XbjQfNe3bD6so
# 6   spotify:track:1GcVa4jFySlun4jLSuMhiq
# 7   spotify:track:52dm9op3rbfAkc1LGXgipW
# 8   spotify:track:3hJLKtTpgct9Y9wKww0BiR
# 9   spotify:track:61UuPxxYUvacEH6SHIK3sU
#
# [200 rows x 2 columns]
